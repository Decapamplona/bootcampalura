# %% [markdown]
# <a href="https://colab.research.google.com/github/Decapamplona/bootcampalura/blob/main/C%C3%B3pia_de_camp1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
dados = pd.read_csv("/content/A013314189_28_143_208.csv", encoding= 'Iso-8859-1',skiprows = 3, sep=";", skipfooter= 12, thousands='.', decimal=',')
dados
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unidade da Federação  1992/Mar  ...      2020/Dez         Total
# 0              11 Rondônia         -  ...  3.429070e+06  9.683913e+08
# 1                  12 Acre         -  ...  1.039798e+06  4.387173e+08
# 2              13 Amazonas         -  ...  5.660135e+06  1.847868e+09
# 3               14 Roraima         -  ...  1.735511e+06  3.181047e+08
# 4                  15 Pará         -  ...  1.258447e+07  4.595990e+09
# 5                 16 Amapá         -  ...  5.978343e+05  3.010511e+08
# 6             17 Tocantins         -  ...  3.181577e+05  1.017932e+09
# 7              21 Maranhão         -  ...  1.074468e+07  3.769743e+09
# ...

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Dez         Total
# 0          11 Rondônia        -  ...   3429070.34  9.683913e+08
# 1              12 Acre        -  ...   1039798.08  4.387173e+08
# 2          13 Amazonas        -  ...   5660135.46  1.847868e+09
# 3           14 Roraima        -  ...   1735511.41  3.181047e+08
# 4              15 Pará        -  ...  12584469.19  4.595990e+09
#
# [5 rows x 284 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Dez         Total
# 22   43 Rio Grande do Sul        -  ...  29435091.82  1.240245e+10
# 23  50 Mato Grosso do Sul        -  ...   2573368.31  2.253326e+09
# 24         51 Mato Grosso        -  ...   7761853.18  2.123039e+09
# 25               52 Goiás        -  ...  17495055.06  4.839109e+09
# 26    53 Distrito Federal        -  ...   9767544.38  2.514297e+09
#
# [5 rows x 284 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 284 entries, Unidade da Federação to Total
# dtypes: float64(162), object(122)
# memory usage: 60.0+ KB

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Set    5.190758e+07
# 2020/Out    4.719043e+07
# 2020/Nov    3.780037e+07
# 2020/Dez    1.884927e+07
# Total       6.214052e+09
# Length: 162, dtype: float64

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Set     51907581.40
# 2020/Out     47190426.27
# 2020/Nov     37800374.55
# 2020/Dez     18849270.20
# Total      6214051709.44
# Length: 162, dtype: float64

# %%
dados['2008/Ago']
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42496357.18
# 19   179959634.14
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21050641.87
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados.plot()

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(11,7))
import matplotlib.ticker as ticker 
plt.title('VALOR GASTO COM PROCEDIMENTOS HOSPITALARES POR FEDERAÇÃO')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Mar', kind='bar', figsize=(11,7))
import matplotlib.ticker as ticker
plt.title('VALOR GASTO COM PROCEDIMENTOS HOSPITALARES POR FEDERAÇÃO')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Nov', kind='bar', figsize=(11,7))
import matplotlib.ticker as ticker
plt.title('VALOR GASTO COM PROCEDIMENTOS HOSPITALARES POR FEDERAÇÃO')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %%
dados_sort = dados[["Unidade da Federação", "2008/Mar"]].sort_values(by = "2008/Mar", ascending = False)
ax = dados_sort.plot(x="Unidade da Federação", y = "2008/Mar", kind ="bar", figsize=(10,6), legend=None, color="purple",)
plt.title('VALOR GASTO COM PROCEDIMENTOS HOSPITALARES POR FEDERAÇÃO EM MARÇO/08')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.style.use('dark_background')
plt.show()
####DESAFIO 1 E 2.

# %%
dados[[ '2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Set     51907581.40
# 2020/Out     47190426.27
# 2020/Nov     37800374.55
# 2020/Dez     18849270.20
# Total      6214051709.44
# Length: 162, dtype: float64

# %%
colunas_usaveis = dados.mean().index
colunas_usaveis
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Abr', '2020/Mai', '2020/Jun', '2020/Jul', '2020/Ago', '2020/Set',
#        '2020/Out', '2020/Nov', '2020/Dez', 'Total'],
#       dtype='object', length=162)

# %%
dados[colunas_usaveis] #sumiu a coluna unidade da federação, devemos incluir com tolist...insert(0, ' unidade da federação')
# Out:
#      2007/Ago   2007/Set    2007/Out  ...     2020/Nov     2020/Dez          Total
# 0     4209.37   16397.03   133645.19  ...   6512472.15   3429070.34   968391333.58
# 1    10470.07   14001.71    86200.85  ...   2201264.05   1039798.08   438717333.51
# 2    35752.72   45570.64   416012.30  ...  13115540.22   5660135.46  1847868336.11
# 3     4785.91   11858.63    43852.67  ...   2888884.51   1735511.41   318104732.81
# 4   181159.29  433414.74  1893197.50  ...  26725835.92  12584469.19  4595989612.71
# 5    33672.74  104822.98   118378.28  ...   1448075.77    597834.30   301051145.96
# 6     4113.76   76633.06   343702.61  ...    476687.76    318157.73  1017931806.95
# 7   385330.18 1018352.93  2277717.78  ...  22481959.73  10744681.21  3769742585.26
# 8   220788.25  353468.67  1078182.68  ...  14441283.96   7926748.48  2218780817.66
# 9   357904.65  572356.18  1865065.71  ...  29584212.96  13727062.08  6424507559.35
# ...

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis= dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Dez         Total
# 0          11 Rondônia   4209.37  ...  3429070.34  968391333.58
# 1              12 Acre  10470.07  ...  1039798.08  438717333.51
# 2          13 Amazonas  35752.72  ...  5660135.46 1847868336.11
# 3           14 Roraima   4785.91  ...  1735511.41  318104732.81
# 4              15 Pará 181159.29  ... 12584469.19 4595989612.71
#
# [5 rows x 163 columns]

# %%
usaveis = usaveis.set_index('Unidade da Federação')
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Dez          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   3429070.34   968391333.58
# 12 Acre                  10470.07   14001.71  ...   1039798.08   438717333.51
# 13 Amazonas              35752.72   45570.64  ...   5660135.46  1847868336.11
# 14 Roraima                4785.91   11858.63  ...   1735511.41   318104732.81
# 15 Pará                 181159.29  433414.74  ...  12584469.19  4595989612.71
# 16 Amapá                 33672.74  104822.98  ...    597834.30   301051145.96
# 17 Tocantins              4113.76   76633.06  ...    318157.73  1017931806.95
# 21 Maranhão             385330.18 1018352.93  ...  10744681.21  3769742585.26
# 22 Piauí                220788.25  353468.67  ...   7926748.48  2218780817.66
# 23 Ceará                357904.65  572356.18  ...  13727062.08  6424507559.35
# ...

# %%
usaveis['2009/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    3787323.26
# 12 Acre        1714707.91
# 13 Amazonas    9267006.58
# 14 Roraima     1529696.18
# 15 Pará       27892582.69
# Name: 2009/Ago, dtype: float64

# %%
usaveis.loc['12 Acre'] # localiza a linha 12 acre
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Set     3186517.29
# 2020/Out     2804839.14
# 2020/Nov     2201264.05
# 2020/Dez     1039798.08
# Total      438717333.51
# Name: 12 Acre, Length: 162, dtype: float64

# %%
usaveis.T.head() # T rotaciona na tabela.
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot() #esse grafico ficou assim pq no final temos o total dos gastos e que temos que eliminar

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Set               8650051.23  ...          21152926.43
# 2020/Out               7424388.60  ...          20500543.15
# 2020/Nov               6512472.15  ...          15285253.80
# 2020/Dez               3429070.34  ...           9767544.38
# Total                968391333.58  ...        2514296933.20
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop('Total', axis=1)
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Nov     2020/Dez
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   6512472.15   3429070.34
# 12 Acre                  10470.07   14001.71  ...   2201264.05   1039798.08
# 13 Amazonas              35752.72   45570.64  ...  13115540.22   5660135.46
# 14 Roraima                4785.91   11858.63  ...   2888884.51   1735511.41
# 15 Pará                 181159.29  433414.74  ...  26725835.92  12584469.19
# 16 Amapá                 33672.74  104822.98  ...   1448075.77    597834.30
# 17 Tocantins              4113.76   76633.06  ...    476687.76    318157.73
# 21 Maranhão             385330.18 1018352.93  ...  22481959.73  10744681.21
# 22 Piauí                220788.25  353468.67  ...  14441283.96   7926748.48
# 23 Ceará                357904.65  572356.18  ...  29584212.96  13727062.08
# 24 Rio Grande do Norte  134605.36  272088.08  ...  18618811.03   7697901.17
# ...

# %% [markdown]
# DESAFIO 1

# %%
ax = usaveis.T.plot(figsize=(15,10))
plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.title('TOTAL DE ATENDIMENTO POR FEDERAÇÃO')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()
##DESAFIO 1

# %% [markdown]
# DESAFIO 2

# %%
cinco_estados = usaveis.loc[['11 Rondônia', '12 Acre','13 Amazonas','14 Roraima','15 Pará']]
ax = cinco_estados.T.plot(figsize=(15,10))
plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.title('TOTAL DE ATENDIMENTO POR FEDERAÇÃO-NORTE')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()
